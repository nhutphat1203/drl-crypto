# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import talib as ta

# %%
path = '../dataprocessed/binance_BTC_USDT_processed.csv'
prd = pd.read_csv(path, index_col="datetime", parse_dates=True)

# %%
data = prd.loc[:, [col for col in prd.columns if col not in ["open", "high", "low", "close", "volume"]]]
data.head(5)
# Out:
#                      log_time_gap  hour_sin  hour_cos  body_ratio  log_ret_1  \
# datetime
# 2020-01-01 00:00:00           0.0  0.000000  1.000000   -0.876383  -0.002534
# 2020-01-01 01:00:00           0.0  0.258819  0.965926    0.733100   0.005454
# 2020-01-01 02:00:00           0.0  0.500000  0.866025    0.816796   0.003677
# 2020-01-01 03:00:00           0.0  0.707107  0.707107   -0.706000  -0.002466
# 2020-01-01 04:00:00           0.0  0.866025  0.500000   -0.516366  -0.001072
#
#                      log_ret_4  log_ret_24  volatility_4  volatility_24_ratio  \
# datetime
# 2020-01-01 00:00:00   0.000085   -0.010255      0.002062             0.868509
# 2020-01-01 01:00:00   0.004177   -0.006785      0.003478             1.327332
# 2020-01-01 02:00:00   0.005867   -0.000571      0.003724             1.382640
# 2020-01-01 03:00:00   0.004130   -0.001574      0.004143             1.520771
# 2020-01-01 04:00:00   0.005593   -0.003196      0.003772             1.382208
#
# ...

# %%
data.describe()
# Out:
#        log_time_gap      hour_sin      hour_cos    body_ratio     log_ret_1  \
# count  54736.000000  54736.000000  5.473600e+04  54736.000000  54736.000000
# mean       0.000291     -0.000192 -3.083244e-05      0.011636      0.000041
# std        0.018736      0.707103  7.071236e-01      0.496053      0.006671
# min        0.000000     -1.000000 -1.000000e+00     -1.000000     -0.201033
# 25%        0.000000     -0.707107 -7.071068e-01     -0.408345     -0.002325
# 50%        0.000000      0.000000 -1.836970e-16      0.014229      0.000061
# 75%        0.000000      0.707107  7.071068e-01      0.432069      0.002504
# max        1.791759      1.000000  1.000000e+00      1.000000      0.160280
#
#           log_ret_4    log_ret_24  volatility_4  volatility_24_ratio  \
# count  54736.000000  54736.000000  54736.000000         54736.000000
# mean       0.000164      0.000979      0.004891             0.895114
# std        0.013044      0.031927      0.004608             0.474301
# ...
